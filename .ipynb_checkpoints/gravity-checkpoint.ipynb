# %% [markdown]
# # Gravity Modelling
#
# Example of gravity potential field of a Prisma and a Point source

# %%
# %matplotlib inline

from Gravity.modelling import model_gravity

# %%
for i in [1, 10]:
    model_gravity(scal=i)
# Out:
# 0 |                                                        | 100---------------------------------------------------
# 0 |                                                        | 100---------------------------------------------------
