# %% [markdown]
# # Applied Geophysics  (2018): Assignment 2
#
# ### Student: Vegeta, the Prince of Sayans
# ### Number: over 9000

# %% [markdown]
# ## Gravity Modelling
#
# Example of gravity potential field of a Prisms and a Point masses

# %% [markdown]
# First, import necessary libraries

# %%
# %matplotlib inline

from Gravity.modelling import model_gravity, hollow_sphere

# %% [markdown]
# ## Modelling examples
#
# Modelling by **point mass**

# %%
for i in [1, 2]:
    model_gravity('point',scal=i)
# Out:
# ---------------------------------------------------
# ---------------------------------------------------

# %% [markdown]
# Then, **prism-based** modelling...

# %%
for i in [1, 2]:
    model_gravity('prisma',scal=i)
# Out:
# ---------------------------------------------------
# ---------------------------------------------------

# %% [markdown]
# ## A special case: hollow spheres
#
# Here's a field for a hollow sphere...

# %%
hollow_sphere()

# %% [markdown]
# ### What is going on in these examples?
#
# Based on the assignment instructions, build on this Notebook to complete the assignment.
#
# **Note**: the Assignment asks you to comment code.... 'but **how**', you ask?
#
# Well, like so.
#
# First, use any software/text editor you'd like. Then, open the source code/script, for example: *modelling.py* .
#
# Then copy a section of code you wish to talk about and comment. You can then paste it here, into your Markdown cell, like so:
#
# ```
# # THIS IS A COMMENT IN PYTHON
# def model_gravity(object='all', scal=1):
#     """
#     object: 'prisma', 'point' or 'all'
#     """
#
#     nstart = -1E3
#     nend = 1E3
#     nstep = 2E1
#     x = scal * np.arange(nstart, nend+nstep, nstep) + 1E-3
#     y = scal * np.arange(nstart, nend+nstep, nstep) + 1E-3
#     z = (scal)**1.5*1.1E2
#
# ```
#
# Then write/say what you'd like, e.g.:
#
# I have **absolutely no idea** what is going on!
